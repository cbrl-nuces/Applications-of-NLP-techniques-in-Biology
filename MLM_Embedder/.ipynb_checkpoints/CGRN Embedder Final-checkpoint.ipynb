# %%
import os
import numpy as np
from tqdm import tqdm
os.environ['CUDA_VISIBLE_DEVICES'] = "1"

import tensorflow as tf
import tensorflow.keras as tfk
from sklearn.metrics import *
import copy
import numpy as np
import matplotlib.pyplot as plt
import pickle
# Out:
# 2023-04-30 14:41:49.957069: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None
if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
    #strategy = tf.distribute.MirroredStrategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
num_aminoAcids = {0:'A', 1:'C', 2:'E', 3:'D', 4:'G', 5:'F', 6:'I', 7:'H', 8:'K', 9:'M', 10:'L',
            11:'N', 12:'Q', 13:'P', 14:'S', 15:'R', 16:'T', 17:'W', 18:'V', 19:'Y', 20:'X'}
embedding_keys = {
        '<pad>':0,
        'A':1,
        'C':2,
        'D':3,
        'E':4,
        'F':5,
        'G':6,
        'H':7,
        'I':8,
        'K':9,
        'L':10,
        'M':11,
        'N':12,
        'P':13,
        'Q':14,
        'R':15,
        'S':16,
        'T':17,
        'V':18,
        'W':19,
        'X':20,
        'Y':21,
        'B':22,
        'U':23,
        'Z':24,
        'O':25,
        '<mask>':26}
embedding_list = list(embedding_keys)

# %%
class NonZeroCCE(tf.keras.losses.Loss):
    def __init__(self,Weights=[],smoothing = None):
        super().__init__()
        if smoothing is not None:
            self.cce = tf.keras.losses.CategoricalCrossentropy(reduction='none', label_smoothing=smoothing)
        else:
            self.cce = tf.keras.losses.CategoricalCrossentropy(reduction='none')
        self.weights = np.array(Weights)
    def call(self, y_true, y_pred):
        if len(self.weights)>0:
            loss = self.cce(self.weights*y_true,y_pred)
        else:
            loss = self.cce(y_true,y_pred)
        return tf.math.reduce_sum(loss)/((y_true.shape[0]*y_true.shape[1])-float(tf.math.reduce_sum(tf.cast(tf.equal(tf.math.reduce_sum(y_true,-1),0),tf.int32))))

def Accuracy(y_true,y_pred):
    y_true = y_true.numpy()
    y_pred = y_pred.numpy()

    m = np.sum(y_true, axis=-1)
    y_t = np.argmax(y_true[m==1],axis=-1)
    y_p = np.argmax(y_pred[m==1],axis=-1)
    return accuracy_score(y_t,y_p)

def dump_pickle(path,files):
    with open(path, 'wb') as f:
        pickle.dump(files, f)
def load_pickle(path):
    with open(path, 'rb') as f:
        files = pickle.load(f)
    return files

def plot_hist(files):    
    lens = []
    for idx in tqdm(range(len(files))):
        path = files[idx]
        protein_sequence = np.load(path)
        lens.append(len(protein_sequence))
    plt.hist(lens)
    plt.show()

# %%
class MLM_Loader(tfk.utils.Sequence):
    def __init__(self, files, batch_size=30, shuffle=True, masked_perc=0.0, max_seq_len=2000, train=False,loss="MASKED"):
        self.files = files
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.masked_perc = masked_perc
        self.loss = loss
        self.max_seq_len = max_seq_len
        self.mask = embedding_keys['<mask>']
        self.length = len(files)
        self.indices = np.arange(0,self.length)
        self.train = train
        self.on_epoch_end()
        
    def generateBatches(self):
        self.files_ = self.files[self.indices]
    
    def mask_data(self, protein_sequence, length):
        temp_label = copy.deepcopy(protein_sequence)
        choices = np.random.choice(3, length, p=[1-self.masked_perc,self.masked_perc*0.8,self.masked_perc*0.2])
        if True in (choices==1) or True in (choices==2):
            protein_sequence[:length][choices==1] = self.mask
            protein_sequence[:length][choices==2] = np.random.choice(25, np.sum(choices==2))+1
            if self.loss=="MASKED":
                temp_label[:length][choices==0] = 0
        return (protein_sequence,temp_label)
    
    #Convert Amino Acids to their IDs and pad with <pad> token if size<max_seq_len
    def preprocess(self,protein_sequence):
        length = len(protein_sequence)
        protein_sequence = np.concatenate((protein_sequence, [0]*(self.max_seq_len-len(protein_sequence))), axis=0)
        if self.masked_perc>0.0:
            protein_sequence,true_label = self.mask_data(protein_sequence,length)
        else:
            true_label = copy.deepcopy(protein_sequence)
        return np.array([protein_sequence,true_label])

    def fetch_data(self, path):
        return self.preprocess(np.load(path))

    def on_epoch_end(self):
        seed_value = np.random.randint(1,100)
        #print("Seed Value:",seed_value)
        np.random.seed(seed_value)
        if self.shuffle:
            np.random.shuffle(self.indices)
        self.generateBatches()
        
    def __getitem__(self,index):
        data = np.array([self.fetch_data(file) for file in self.files_[index*self.batch_size:(index+1)*self.batch_size]])
        prot_seq = data[:,0,:]
        labels = data[:,1,:]
        labels = np.array(tf.one_hot(labels,len(embedding_keys))[:,:,1:len(embedding_keys)-1])
        prot_seq = np.array(prot_seq)
        labels = np.array(labels)
        if self.train:
            return ([
                    prot_seq
                   ],
                    labels
                   )
        else:
            return [prot_seq]

    def __len__(self):
        if self.length%self.batch_size!=0:
            return (self.length//self.batch_size)+1
        return self.length//self.batch_size

# %%
with strategy.scope():
    input1_ = tfk.layers.Input(shape=(2000,), name='sequence_input')
    
    emb = tfk.layers.Embedding(input_dim=len(embedding_keys), output_dim=1000, name='embds')(input1_)
    #Embedder
    x1 = tfk.layers.Conv1D( 100, 11, strides=1, padding='same', activation='relu')(emb)
    x2 = tfk.layers.Conv1D( 100, 7, strides=1, padding='same', activation='relu')(emb)
    x3 = tfk.layers.Conv1D( 100, 3, strides=1, padding='same', activation='relu')(emb)
    x = tfk.layers.concatenate([x1, x2, x3], axis=-1)
    
    x1 = tfk.layers.Conv1D( 100, 11, strides=1, padding='same', activation='relu')(x)
    x2 = tfk.layers.Conv1D( 100, 7, strides=1, padding='same', activation='relu')(x)
    x3 = tfk.layers.Conv1D( 100, 3, strides=1, padding='same', activation='relu')(x)
    x = tfk.layers.concatenate([x1, x2, x3], axis=-1)
    
    x1 = tfk.layers.Conv1D( 100, 11, strides=1, padding='same', activation='relu')(x)
    x2 = tfk.layers.Conv1D( 100, 7, strides=1, padding='same', activation='relu')(x)
    x3 = tfk.layers.Conv1D( 100, 3, strides=1, padding='same', activation='relu')(x)
    x = tfk.layers.concatenate([x1, x2, x3], axis=-1)

    gru_out = tfk.layers.Bidirectional(tfk.layers.GRU(units=150, return_sequences=True), name='bigru1')(emb)
    gru_out2 = tfk.layers.Bidirectional(tfk.layers.GRU(units=150, return_sequences=True), name='bigru2')(gru_out)
    x = tfk.layers.concatenate([gru_out2, x], axis=-1)
    
    x = tfk.layers.TimeDistributed( tfk.layers.Dense(500, activation='relu'), name='output1')(x)
    x = tfk.layers.TimeDistributed( tfk.layers.Dense(500, activation='relu'), name='output2')(x)
    output_ = tfk.layers.TimeDistributed( tfk.layers.Dense(len(embedding_keys)-2, activation='softmax') ,name='output')(x)
    model = tfk.models.Model([input1_], output_)
    model.compile(loss=NonZeroCCE(), metrics=[Accuracy], optimizer='adam', run_eagerly = True)
    
    model.summary()
# Out:
# 2023-04-30 14:41:55.792044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-30 14:41:55.809699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-30 14:41:55.810348: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-30 14:41:55.811255: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# ...

# %%
model.load_weights('./Weights/Embedder_CGRN_100.h5')

# %%
#Embedder for Conv
conv_embedder = tfk.models.Model([model.inputs], model.layers[15].output)
conv_embedder.compile(loss="categorical_crossentropy", metrics=[Accuracy], optimizer='adam', run_eagerly = True)
conv_embedder.summary()

#Embedder for GRU
gru_embedder = tfk.models.Model([model.inputs], model.layers[14].output)
gru_embedder.compile(loss="categorical_crossentropy", metrics=[Accuracy], optimizer='adam', run_eagerly = True)
gru_embedder.summary()

#Embedder for Conv_GRU
conv_gru_embedder = tfk.models.Model([model.inputs], model.layers[16].output)
conv_gru_embedder.compile(loss="categorical_crossentropy", metrics=[Accuracy], optimizer='adam', run_eagerly = True)
conv_gru_embedder.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  sequence_input (InputLayer)    [(None, 2000)]       0           []
#
#  embds (Embedding)              (None, 2000, 1000)   27000       ['sequence_input[0][0]']
#
#  conv1d (Conv1D)                (None, 2000, 100)    1100100     ['embds[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 2000, 100)    700100      ['embds[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 2000, 100)    300100      ['embds[0][0]']
#
#  concatenate (Concatenate)      (None, 2000, 300)    0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 2000, 100)    330100      ['concatenate[0][0]']
#
# ...

# %%
if not os.path.exists("../Disordered_Regions/Data/Embeddings"):
    os.mkdir("../Disordered_Regions/Data/Embeddings")
    for directory in ["Conv","GRU","Conv_GRU"]:
        os.mkdir(os.path.join("../Disordered_Regions/Data/Embeddings",directory))
        for split in ["val","test"]:
            os.mkdir(os.path.join("../Disordered_Regions/Data/Embeddings",directory,split))
if not os.path.exists("../Secondary_Structure/Data/Embeddings"):
    os.mkdir("../Secondary_Structure/Data/Embeddings")
    for directory in ["Conv","GRU","Conv_GRU"]:
        os.mkdir(os.path.join("../Secondary_Structure/Data/Embeddings",directory))
        for split in ["val","test"]:
            os.mkdir(os.path.join("../Secondary_Structure/Data/Embeddings",directory,split))

# %%
#Dataset for IDRP
tmp = np.load('../Disordered_Regions/Data/Disordered_Regions_Train_Dataset.npz')
X = tmp['sequences']
X = np.argmax(X,axis=-1)
X_p = tmp['pssms']
Y = tmp['regions']
X_m = X!=0
X_m = X_m.astype(np.int32)
X_i = np.repeat(np.arange(1,X.shape[1]+1)[None,:], X.shape[0], axis=0)
X_i[X==0] = 0
max_len = X.shape[1]

train_ids = []
with open('../Disordered_Regions/Data/DM3000_id.txt') as f:
    for l in f.readlines():
        if l[:3] == 'Dis':
            k = l.split('|')[1].split()[0]
        else:
            k = l.split()[0]
        train_ids += [k]
val_ids = []
with open('../Disordered_Regions/Data/DM1229_id.txt') as f:
    for l in f.readlines():
        if l[:3] == 'Dis':
            k = l.split('|')[1].split()[0]
        else:
            k = l.split()[0]
        val_ids += [k]
a = tmp['seq_ids']
tr_ids_m = [True if i in train_ids else False for i in a]
val_ids_m = [True if i in val_ids else False for i in a]
len(val_ids),len(train_ids)

X1_val = X[val_ids_m][:,1:1863]
X4_val = X_m[val_ids_m][:,1:1863]
X2_val = X_p[val_ids_m][:,1:1863]
X3_val = X_i[val_ids_m][:,1:1863]
Y_val = Y[val_ids_m][:,1:1863]
X4_val = np.expand_dims(X4_val,-1)
X4_val.shape
#X1_val[X1_val==23]=0


X1 = X[tr_ids_m][:,1:1863]
X4 = X_m[tr_ids_m][:,1:1863]
X2 = X_p[tr_ids_m][:,1:1863]
X3 = X_i[tr_ids_m][:,1:1863]
Y = Y[tr_ids_m][:,1:1863]

X4 = np.expand_dims(X4,-1)
X4.shape

tmp = np.load('../Disordered_Regions/Data/Disordered_Regions_Test_Dataset.npz')
test_ids = []
with open('../Disordered_Regions/Data/SL329_id.txt') as f:
    for l in f.readlines():
        k = l.split('|')[1].split()[0]
        test_ids += [k]
te_ids_m = [True if i in test_ids else False for i in tmp['seq_ids']]
X1_te = np.argmax(tmp['sequences'],axis=-1)[te_ids_m][:,1:1863]
X2_te = tmp['pssms'][te_ids_m][:,1:1863]
Y_te = tmp['regions'][te_ids_m][:,1:1863]
X_m_te = X1_te!=0
X4_te = X_m_te.astype(np.int32)
X4_te = np.expand_dims(X4_te,-1)
X4_te.shape
X1_temp = []
for seq in X1:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)
    else:
        end = end[0]
    X1_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(0,end)])
    X1_temp[-1].extend([0]*(2000-len(X1_temp[-1])))
    X1_temp[-1] = np.array(X1_temp[-1])
X1_temp = np.array(X1_temp)

X1_val_temp = []
for seq in X1_val:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)
    else:
        end = end[0]
    X1_val_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(0,end)])
    X1_val_temp[-1].extend([0]*(2000-len(X1_val_temp[-1])))
    X1_val_temp[-1] = np.array(X1_val_temp[-1])
X1_val_temp = np.array(X1_val_temp)

X1_te_temp = []
for seq in X1_te:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)
    else:
        end = end[0]
    X1_te_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(0,end)])
    X1_te_temp[-1].extend([0]*(2000-len(X1_te_temp[-1])))
    X1_te_temp[-1] = np.array(X1_te_temp[-1])
X1_te_temp = np.array(X1_te_temp)

X1_temp_oneHot = np.array(tf.one_hot(X1_temp,len(embedding_keys))[:,:,1:])
X1_val_temp_oneHot = np.array(tf.one_hot(X1_val_temp,len(embedding_keys))[:,:,1:])
X1_te_temp_oneHot = np.array(tf.one_hot(X1_te_temp,len(embedding_keys))[:,:,1:])

# %%
X1_te_temp.shape
# Out:
# (318, 2000)

# %%
def write_embeddings(path,input_sequences, embedder):
    for idx in tqdm(range(len(input_sequences))):
        embeddings = embedder.predict(input_sequences[idx].reshape(1,2000))
        with open(path+str(idx).zfill(6)+'.npy', 'wb') as f:
            np.save(f, embeddings)
write_embeddings("../Disordered_Regions/Data/Embeddings/Conv/val/",X1_val_temp,conv_embedder)
write_embeddings("../Disordered_Regions/Data/Embeddings/Conv/test/",X1_te_temp,conv_embedder)


write_embeddings("../Disordered_Regions/Data/Embeddings/GRU/val/",X1_val_temp,gru_embedder)
write_embeddings("../Disordered_Regions/Data/Embeddings/GRU/test/",X1_te_temp,gru_embedder)


write_embeddings("../Disordered_Regions/Data/Embeddings/Conv_GRU/val/",X1_val_temp,conv_gru_embedder)
write_embeddings("../Disordered_Regions/Data/Embeddings/Conv_GRU/test/",X1_te_temp,conv_gru_embedder)
# Out:
# ...
# 1/1 [==============================] - 1s 788ms/step
# 2023-04-30 04:10:20.129047: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 04:10:20.129303: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 04:10:20.129318: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-30 04:10:20.129526: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 04:10:20.129561: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ...
# 1/1 [==============================] - 0s 17ms/step
# ...
# ...

# %%
#Dataset for SSP
num_aminoAcids = {0:'A', 1:'C', 2:'E', 3:'D', 4:'G', 5:'F', 6:'I', 7:'H', 8:'K', 9:'M', 10:'L',
            11:'N', 12:'Q', 13:'P', 14:'S', 15:'R', 16:'T', 17:'W', 18:'V', 19:'Y', 20:'X'}
num_ss = {0:'L',1:'B',2:'E',3:'G',4:'I',5:'H',6:'S',7:'T'}
aminoAcid_I = {j:i+1 for i,j in num_aminoAcids.items()}
aminoAcid_I['<pad>'] = 0
aminoAcid_I['<S>'] = len(aminoAcid_I)
aminoAcid_I['<EOS>'] = len(aminoAcid_I)
ss_I = {j:i+1 for i,j in num_ss.items()}
ss_I['<pad>'] = 0
ss_I['X'] = len(ss_I)
ss_I['<S>'] = len(ss_I)
ss_I['<EOS>'] = len(ss_I)

trainDataPath = '../Secondary_Structure/Data/Secondary_Structure_Train_Dataset.npz'
testDataPath = '../Secondary_Structure/Data/Secondary_Structure_Test_Dataset.npz'

tmp = np.load('../Secondary_Structure/Data/Secondary_Structure_Motif_Antimotif.npz')
motifs = tmp['motifs']
antiMotifs = tmp['antimotifs']
len(motifs),len(antiMotifs)
def load_data(file_path):
    data = np.load(file_path)
    sequences = data['sequences']
    pssms = data['pssms']
    secondary_structure = data['secondaryStrucs']

    in1 = np.zeros((sequences.shape[0], 702), dtype=np.int32)
    in2 = np.zeros((sequences.shape[0], 702,22), dtype=np.float32)
    in3 = np.zeros((sequences.shape[0], 702), dtype=np.int32)
    out = np.zeros((sequences.shape[0], 702), dtype=np.int32)
    for i in tqdm(range(sequences.shape[0])):
        seq = '-'
        in1[i,0] = aminoAcid_I['<S>']
        in3[i,0] = 1
        out[i,0] = ss_I['<S>']
        for j in range(sequences.shape[1]):
            if np.sum(sequences[i,j,:]) == 0:
                in1[i,j+1] = aminoAcid_I['<EOS>']
                in3[i,j+1] = j+2
                out[i,j+1] = ss_I['<EOS>']
                break
            in3[i,j+1] = j+2
            t = num_aminoAcids[np.argmax(sequences[i,j,:])]
            seq += t
            in1[i,j+1] = aminoAcid_I[t]
            out[i,j+1] = ss_I[num_ss[np.argmax(secondary_structure[i,j,:])]]
            if np.sum(secondary_structure[i,j,:]) == 0:
                out[i,j+1] = ss_I['X']
            in2[i,j+1] = pssms[i,j]
    in4 = np.where(in1!=0, 1, 0)[:,:,None]
    return in1, in2, in3, in4, out
X1, X2, X3, X4, Y = load_data(trainDataPath)
X1_val = X1[12000:]
X2_val = X2[12000:]
X3_val = X3[12000:]
X4_val = X4[12000:]
Y_val = tf.one_hot(Y[12000:], 9)[:,:,1:]

X1 = X1[:12000]
X2 = X2[:12000]
X3 = X3[:12000]
X4 = X4[:12000]
Y = tf.one_hot(Y[:12000], 9)[:,:,1:]

X1_te, X2_te, X3_te, X4_te, Y_te = load_data(testDataPath)
Y_te = tf.one_hot(Y_te, 9)[:,:,1:]

X1_temp = []
for seq in X1:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)
    else:
        end = end[0]
    X1_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(1,end)])
    X1_temp[-1].extend([0]*(2000-len(X1_temp[-1])))
    X1_temp[-1] = np.array(X1_temp[-1])
X1_temp = np.array(X1_temp)


X1_val_temp = []
for seq in X1_val:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)
    else:
        end = end[0]
    X1_val_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(1,end)])
    X1_val_temp[-1].extend([0]*(2000-len(X1_val_temp[-1])))
    X1_val_temp[-1] = np.array(X1_val_temp[-1])
X1_val_temp = np.array(X1_val_temp)

X1_te_temp = []
i=0
for seq in X1_te:
    end = np.where(seq==23)[0]
    if len(end)==0:
        end = len(seq)-1
    else:
        end = end[0]
    X1_te_temp.append([embedding_keys[num_aminoAcids[seq[idx]-1]] for idx in range(1,end)])
    X1_te_temp[-1].extend([0]*(2000-len(X1_te_temp[-1])))
    X1_te_temp[-1] = np.array(X1_te_temp[-1])
    i+=1
X1_te_temp = np.array(X1_te_temp)

X1_temp_oneHot = np.array(tf.one_hot(X1_temp,len(embedding_keys))[:,:,1:])
X1_val_temp_oneHot = np.array(tf.one_hot(X1_val_temp,len(embedding_keys))[:,:,1:])
X1_te_temp_oneHot = np.array(tf.one_hot(X1_te_temp,len(embedding_keys))[:,:,1:])

X4 = X4[:,1:701,:]
X4_val = X4_val[:,1:701,:]
X4_te = X4_te[:,1:701,:]

X2 = X2[:,1:701,:]
X2_val = X2_val[:,1:701,:]
X2_te = X2_te[:,1:701,:]

Y = Y[:,1:701,:]
Y_val = Y_val[:,1:701,:]
Y_te = Y_te[:,1:701,:]
# Out:
# ...
# 100%|██████████████████████████████████████| 1992/1992 [00:04<00:00, 425.90it/s]
# 2023-04-30 14:42:58.306008: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 2496000000 exceeds 10% of free system memory.

# %%
def write_embeddings_SSP(path,input_sequences,embedder):
    for idx in tqdm(range(len(input_sequences))):
        embeddings = embedder.predict(input_sequences[idx].reshape(1,2000))
        with open(path+str(idx).zfill(6)+'.npy', 'wb') as f:
            np.save(f, embeddings[:,:700,:])

write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/Conv/val/",X1_val_temp,conv_embedder)
write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/Conv/test/",X1_te_temp,conv_embedder)


write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/GRU/val/",X1_val_temp,gru_embedder)
write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/GRU/test/",X1_te_temp,gru_embedder)


write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/Conv_GRU/val/",X1_val_temp,conv_gru_embedder)
write_embeddings_SSP("../Secondary_Structure/Data/Embeddings/Conv_GRU/test/",X1_te_temp,conv_gru_embedder)
# Out:
# ...
# 1/1 [==============================] - 1s 1s/step
# 2023-04-30 14:43:02.176090: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 14:43:02.176353: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 14:43:02.176365: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-04-30 14:43:02.176542: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-30 14:43:02.176577: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ...
# 1/1 [==============================] - 0s 16ms/step
# ...
# ...

# %%
X1_te_temp.shape
# Out:
# (1992, 2000)
